# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.loc[[2,4,6,8,10], ['Survived', 'Name', 'Fare']]
# Out:
#     Survived                                               Name     Fare
# 2          1                             Heikkinen, Miss. Laina   7.9250
# 4          0                           Allen, Mr. William Henry   8.0500
# 6          0                            McCarthy, Mr. Timothy J  51.8625
# 8          1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333
# 10         1                    Sandstrom, Miss. Marguerite Rut  16.7000

# %%
df.loc[4, :]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
df.loc[[1,4], : ]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 4      0    373450   8.0500   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
def test(a):
    return a * a

# %%
lambda a: a * a
# Out:
# <function __main__.<lambda>(a)>

# %%
test(3)
# Out:
# 9

# %%
df['Square_Pclass'] = df['Pclass'].apply(test)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
def test2(a):
    if a == 'male':
        return 1
    else:
        return 0

# %%
df['Nex_sex'] = df['Sex'].apply(test2)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Square_Pclass  Nex_sex
# 0      0         A/5 21171   7.2500   NaN        S              9        1
# 1      0          PC 17599  71.2833   C85        C              1        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              9        0
# ...

# %%
df['New_Fare'] = df['Fare'].apply(lambda a:a/2)

# %%
def test3(a):
    return a/2

# %%
lambda a:a/2

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Square_Pclass  Nex_sex  \
# 0      0         A/5 21171   7.2500   NaN        S              9        1
# 1      0          PC 17599  71.2833   C85        C              1        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              9        0
# ...

# %%
# Concatinate Operations

# %%
df.loc[0:5, ['Name']]
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
d1 = df.loc[0:5, ['Name']]

# %%
d1
# Out:
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
merged = pd.concat([df,d1])

# %%
merged.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 887        888.0       1.0     1.0
# 888        889.0       0.0     3.0
# 889        890.0       1.0     1.0
# 890        891.0       0.0     3.0
# 0            NaN       NaN     NaN
# 1            NaN       NaN     NaN
# 2            NaN       NaN     NaN
# 3            NaN       NaN     NaN
# 4            NaN       NaN     NaN
# 5            NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 887                       Graham, Miss. Margaret Edith  female  19.0    0.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN    1.0
# 889                              Behr, Mr. Karl Howell    male  26.0    0.0
# 890                                Dooley, Mr. Patrick    male  32.0    0.0
# 0                              Braund, Mr. Owen Harris     NaN   NaN    NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...     NaN   NaN    NaN
# ...

# %%
parallel = pd.concat([df,d1], axis=1)

# %%
parallel.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Square_Pclass  Nex_sex  \
# 0      0         A/5 21171   7.2500   NaN        S              9        1
# 1      0          PC 17599  71.2833   C85        C              1        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              9        0
# ...

# %%
Non_dependent = df.iloc[:, :-1]

# %%
Non_dependent.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Square_Pclass  Nex_sex
# 0      0         A/5 21171   7.2500   NaN        S              9        1
# 1      0          PC 17599  71.2833   C85        C              1        0
# 2      0  STON/O2. 3101282   7.9250   NaN        S              9        0
# ...

# %%
l = [1,2,3,4]

# %%
l[:-1]
# Out:
# [1, 2, 3]
