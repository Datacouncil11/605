# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [raw]
# Total male = 577
# Dead Males = 468
# Survived = 109

# %%
df['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
df[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex'] == 'female'].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   314.000000  314.000000  314.000000  261.000000  314.000000
# mean    431.028662    0.742038    2.159236   27.915709    0.694268
# std     256.846324    0.438211    0.857290   14.110146    1.156520
# min       2.000000    0.000000    1.000000    0.750000    0.000000
# 25%     231.750000    0.000000    1.000000   18.000000    0.000000
# 50%     414.500000    1.000000    2.000000   27.000000    0.000000
# 75%     641.250000    1.000000    3.000000   37.000000    1.000000
# max     889.000000    1.000000    3.000000   63.000000    8.000000
#
#             Parch        Fare
# count  314.000000  314.000000
# mean     0.649682   44.479818
# std      1.022846   57.997698
# min      0.000000    6.750000
# 25%      0.000000   12.071875
# 50%      0.000000   23.000000
# 75%      1.000000   55.000000
# max      6.000000  512.329200

# %%
len(df[df['Sex'] == 'female'])
# Out:
# 314

# %%
# Female
Total Count = 314
Dead = 81
Survived = 233

# %%
df['Survived'] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Survived, Length: 891, dtype: bool

# %%
df[(df['Sex'] == 'female')  & (df['Survived'] == 0) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 14            15         0       3
# 18            19         0       3
# 24            25         0       3
# 38            39         0       3
# 40            41         0       3
# ..           ...       ...     ...
# 854          855         0       2
# 863          864         0       3
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[(df['Sex'] == 'female')  & (df['Survived'] == 0) ])
# Out:
# 81

# %%
314 - 81
# Out:
# 233

# %%
len(df[(df['Sex'] == 'female')  & (df['Survived'] == 1) ])
# Out:
# 233

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
Total male = 577
Dead Males = 468
Survived = 109

# %% [markdown]
# # Male Analysis

# %%
total_males = 577

# %% [markdown]
# Percentage Of Dead Males

# %%
(468/total_males) * 100
# Out:
# 81.10918544194108

# %%
total_females = 314

# %%
dead_females = 81

# %%
(dead_females/total_females) * 100
# Out:
# 25.796178343949045

# %%
# Who is travelling in free ----> 0

# %%
df[df['Fare'] == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
def percentage_count(Total_count, Actual_count):
    return (Actual_count/Total_count) * 100

# %%
percentage_count(314, 81)
# Out:
# 25.796178343949045

# %%
df[(df['Survived'] == 0)  & (df['Fare'] == 0) ]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# ...

# %%
len(df[(df['Survived'] == 0)  & (df['Fare'] == 0) ])
# Out:
# 14

# %%
len(df[(df['Survived'] == 1)  & (df['Fare'] == 0) ])
# Out:
# 1

# %%
percentage_count(15, 1)
# Out:
# 6.666666666666667

# %%
(1/15)*100
# Out:
# 6.666666666666667

# %%
percentage_count(15,14)
# Out:
# 93.33333333333333

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'] == 512.3292
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare'] == 512.3292]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
percentage_count(0,3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 percentage_count(0,3)
#
# Cell In[23], line 2, in percentage_count(Total_count, Actual_count)
#       1 def percentage_count(Total_count, Actual_count):
# ----> 2     return (Actual_count/Total_count) * 100
#
# ZeroDivisionError: division by zero

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)
